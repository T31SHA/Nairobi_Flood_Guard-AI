# %% [markdown]
# ## 1. Import Data and EDA
#
# Descriptions of the columns are available [here](./Data/floods_description.md)

# %%
import geopandas as gpd

df = gpd.read_file('../../Data/floods.gpkg')

df.head()
# Out:
#                      ward          subcounty  county  pop2009  flooded  \
# 0                  WABERA  Isiolo Sub County  ISIOLO  17431.0        0
# 1    North Kamagambo Ward   Rongo Sub County  Migori  18755.0        0
# 2  Central Kamagambo Ward   Rongo Sub County  Migori  27756.0        0
# 3    South Kamagambo Ward   Rongo Sub County  Migori  27179.0        0
# 4        North Sakwa Ward  Awendo Sub County  Migori  22874.0        0
#
#    rain_cumulative_mm  rain_max_daily_mm  rain_preflood_7d_mm  \
# 0            0.000000           0.000000             0.000000
# 1          258.608840          14.135786            39.955728
# 2          125.951383           8.779010            20.537484
# 3           45.941367           5.696220            10.762588
# 4           78.351185           4.580237            10.795914
#
#    elevation_mean_m  elevation_min_m  elevation_max_m  slope_mean_deg  \
# 0       1099.219448           1026.0           1177.0        1.413028
# 1       1405.549444           1350.0           1508.0        2.246821
# 2       1462.532567           1387.0           1534.0        3.392240
# 3       1490.546337           1363.0           1638.0        4.263301
# 4       1376.935386           1287.0           1617.0        3.834336
#
#                                             geometry
# 0  MULTIPOLYGON (((37.59968 0.40029, 37.59976 0.4...
# 1  MULTIPOLYGON (((34.59938 -0.65054, 34.60006 -0...
# 2  MULTIPOLYGON (((34.61175 -0.73357, 34.61183 -0...
# 3  MULTIPOLYGON (((34.61751 -0.87293, 34.6175 -0....
# 4  MULTIPOLYGON (((34.55349 -0.75193, 34.55364 -0...

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ward                 1450 non-null   object
#  1   subcounty            1450 non-null   object
#  2   county               1450 non-null   object
#  3   pop2009              1450 non-null   float64
#  4   flooded              1450 non-null   int64
#  5   rain_cumulative_mm   1450 non-null   float64
#  6   rain_max_daily_mm    1450 non-null   float64
#  7   rain_preflood_7d_mm  1450 non-null   float64
#  8   elevation_mean_m     1450 non-null   float64
#  9   elevation_min_m      1450 non-null   float64
#  10  elevation_max_m      1450 non-null   float64
#  11  slope_mean_deg       1450 non-null   float64
#  12  geometry             1450 non-null   geometry
# dtypes: float64(8), geometry(1), int64(1), object(3)
# memory usage: 147.4+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 2. Create features and target
#
# I will engineer a new feature: `elevation_range_m`, that is the difference between the maximum (`elevation_max_m`) and minimum (`elevation_min_m`) elevations. This is important because places with steeper slopes i.e. greater elevation ranges tend to flood less compared to flat areas with lower elevation ranges.

# %%
df['elevation_range_m'] = df['elevation_max_m'] - df['elevation_min_m']

df.head()
# Out:
#                      ward          subcounty  county  pop2009  flooded  \
# 0                  WABERA  Isiolo Sub County  ISIOLO  17431.0        0
# 1    North Kamagambo Ward   Rongo Sub County  Migori  18755.0        0
# 2  Central Kamagambo Ward   Rongo Sub County  Migori  27756.0        0
# 3    South Kamagambo Ward   Rongo Sub County  Migori  27179.0        0
# 4        North Sakwa Ward  Awendo Sub County  Migori  22874.0        0
#
#    rain_cumulative_mm  rain_max_daily_mm  rain_preflood_7d_mm  \
# 0            0.000000           0.000000             0.000000
# 1          258.608840          14.135786            39.955728
# 2          125.951383           8.779010            20.537484
# 3           45.941367           5.696220            10.762588
# 4           78.351185           4.580237            10.795914
#
#    elevation_mean_m  elevation_min_m  elevation_max_m  slope_mean_deg  \
# 0       1099.219448           1026.0           1177.0        1.413028
# 1       1405.549444           1350.0           1508.0        2.246821
# 2       1462.532567           1387.0           1534.0        3.392240
# 3       1490.546337           1363.0           1638.0        4.263301
# 4       1376.935386           1287.0           1617.0        3.834336
#
#                                             geometry  elevation_range_m
# 0  MULTIPOLYGON (((37.59968 0.40029, 37.59976 0.4...              151.0
# 1  MULTIPOLYGON (((34.59938 -0.65054, 34.60006 -0...              158.0
# 2  MULTIPOLYGON (((34.61175 -0.73357, 34.61183 -0...              147.0
# 3  MULTIPOLYGON (((34.61751 -0.87293, 34.6175 -0....              275.0
# 4  MULTIPOLYGON (((34.55349 -0.75193, 34.55364 -0...              330.0

# %%
df.columns
# Out:
# Index(['ward', 'subcounty', 'county', 'pop2009', 'flooded',
#        'rain_cumulative_mm', 'rain_max_daily_mm', 'rain_preflood_7d_mm',
#        'elevation_mean_m', 'elevation_min_m', 'elevation_max_m',
#        'slope_mean_deg', 'geometry', 'elevation_range_m'],
#       dtype='object')

# %%
# Drop geometry and metadata columns
feature_columns = [
    'pop2009',
    'rain_cumulative_mm',
    'rain_max_daily_mm',
    'rain_preflood_7d_mm',
    'elevation_mean_m',
    'elevation_min_m',
    'elevation_max_m',
    'elevation_range_m',
    'slope_mean_deg'
]

target_column = 'flooded'

# Features
X = df[feature_columns]
y = df[target_column]

X.head()
# Out:
#    pop2009  rain_cumulative_mm  rain_max_daily_mm  rain_preflood_7d_mm  \
# 0  17431.0            0.000000           0.000000             0.000000
# 1  18755.0          258.608840          14.135786            39.955728
# 2  27756.0          125.951383           8.779010            20.537484
# 3  27179.0           45.941367           5.696220            10.762588
# 4  22874.0           78.351185           4.580237            10.795914
#
#    elevation_mean_m  elevation_min_m  elevation_max_m  elevation_range_m  \
# 0       1099.219448           1026.0           1177.0              151.0
# 1       1405.549444           1350.0           1508.0              158.0
# 2       1462.532567           1387.0           1534.0              147.0
# 3       1490.546337           1363.0           1638.0              275.0
# 4       1376.935386           1287.0           1617.0              330.0
#
#    slope_mean_deg
# 0        1.413028
# 1        2.246821
# 2        3.392240
# 3        4.263301
# 4        3.834336

# %% [markdown]
# ## 3. Preprocessing
#
# First perform standard **train-test split**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2026, stratify=y, test_size=0.3)

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1015 entries, 454 to 845
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pop2009              1015 non-null   float64
#  1   rain_cumulative_mm   1015 non-null   float64
#  2   rain_max_daily_mm    1015 non-null   float64
#  3   rain_preflood_7d_mm  1015 non-null   float64
#  4   elevation_mean_m     1015 non-null   float64
#  5   elevation_min_m      1015 non-null   float64
#  6   elevation_max_m      1015 non-null   float64
#  7   elevation_range_m    1015 non-null   float64
#  8   slope_mean_deg       1015 non-null   float64
# dtypes: float64(9)
# memory usage: 79.3 KB

# %% [markdown]
# For neural networks, standardization of the features and targets has to be done.
#
# `y` is a binary column. Thus, it does not need to be standardized

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_scaled.shape
# Out:
# (1015, 9)

# %% [markdown]
# Due to the limited size of the dataset, we will not have validation data.

# %% [markdown]
# ## 4. Modelling
#
# I will use Keras' API to build the ANN.
#
# I will ensure I use a balanced class weight to account for class imbalance
#
# I will experiment with three types of regularization to see which results in the best metrics:
#  - l1 regularization
#  - l2 regularization
#  - dropout regularization
#
# I will also build a model that implements **Early Stopping**
#
# I will start by building a baseline model that has no regularization whatsoever

# %%
# Computing class weights
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y),
    y=y
)

class_dict = dict(enumerate(class_weights))

class_dict # These are weights required to ensure the classes are handled fairly by the model
# Out:
# {0: 0.6342957130358705, 1: 2.3615635179153096}

# %%
# Baseline model
import keras
from keras import models, layers

# Instantiate
baseline_model = models.Sequential()
input_shape = (X_train_scaled.shape[1],)

# Add input layer
baseline_model.add(layers.Input(input_shape))

# Add hidden layers
baseline_model.add(layers.Dense(50, activation='relu'))
baseline_model.add(layers.Dense(25, activation='relu'))

# Add output layer
baseline_model.add(layers.Dense(1, activation='sigmoid'))

# Define a helper function to compile and fit the model and return history
def compile_and_fit(model, X_train=X_train_scaled, y_train=y_train, class_dict=class_dict, early_stopping=False, callbacks=None, n_epochs=100):
    # Compile
    model.compile(
        optimizer='sgd',
        loss='binary_crossentropy',
        # I will track recall, auc, f1-score and accuracy
        metrics=[
            'accuracy',
            keras.metrics.Recall(name='recall'),
            keras.metrics.AUC(name='auc'),
            keras.metrics.F1Score(threshold=0.5, average='micro')
        ]
    )

    # Fit the model
    if early_stopping:
        history = model.fit(
            X_train,
            y_train,
            epochs=n_epochs,
            batch_size=200,
            class_weight=class_dict,
            callbacks=callbacks
        )
    else:
        history = model.fit(
            X_train,
            y_train,
            epochs=n_epochs,
            batch_size=200,
            class_weight=class_dict
        )

    # Return model training history
    return history
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778574131.857936   63761 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# W0000 00:00:1778574140.248520   66066 cuda_executor.cc:1755] Failed to determine cuDNN version (Note that this is expected if the application doesn't link the cuDNN plugin): INTERNAL: cuDNN error: CUDNN_STATUS_INTERNAL_ERROR
# W0000 00:00:1778574143.637202   63761 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
baseline_history = compile_and_fit(baseline_model)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.3911 - auc: 0.4367 - f1_score: 0.2929 - loss: 0.7293 - recall: 0.5953
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4217 - auc: 0.4883 - f1_score: 0.3230 - loss: 0.7137 - recall: 0.6512
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4345 - auc: 0.5376 - f1_score: 0.3341 - loss: 0.6992 - recall: 0.6698
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4680 - auc: 0.5766 - f1_score: 0.3510 - loss: 0.6864 - recall: 0.6791
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4847 - auc: 0.6117 - f1_score: 0.3645 - loss: 0.6745 - recall: 0.6977
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5153 - auc: 0.6381 - f1_score: 0.3740 - loss: 0.6647 - recall: 0.6837
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5389 - auc: 0.6634 - f1_score: 0.3906 - loss: 0.6546 - recall: 0.6977
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5685 - auc: 0.6834 - f1_score: 0.4081 - loss: 0.6461 - recall: 0.7023
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5961 - auc: 0.7014 - f1_score: 0.4258 - loss: 0.6377 - recall: 0.7070
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6217 - auc: 0.7183 - f1_score: 0.4451 - loss: 0.6287 - recall: 0.7163
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6394 - auc: 0.7315 - f1_score: 0.4554 - loss: 0.6222 - recall: 0.7116
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6621 - auc: 0.7428 - f1_score: 0.4715 - loss: 0.6158 - recall: 0.7116
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6749 - auc: 0.7537 - f1_score: 0.4828 - loss: 0.6097 - recall: 0.7163
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6946 - auc: 0.7641 - f1_score: 0.4984 - loss: 0.6039 - recall: 0.7163
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7172 - auc: 0.7737 - f1_score: 0.5144 - loss: 0.5981 - recall: 0.7070
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7291 - auc: 0.7801 - f1_score: 0.5250 - loss: 0.5941 - recall: 0.7070
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7941 - auc: 0.8668 - f1_score: 0.6151 - loss: 0.4660 - recall: 0.7767
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7931 - auc: 0.8668 - f1_score: 0.6140 - loss: 0.4654 - recall: 0.7767
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7931 - auc: 0.8670 - f1_score: 0.6140 - loss: 0.4646 - recall: 0.7767
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7911 - auc: 0.8673 - f1_score: 0.6131 - loss: 0.4639 - recall: 0.7814
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7911 - auc: 0.8674 - f1_score: 0.6131 - loss: 0.4633 - recall: 0.7814
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7921 - auc: 0.8672 - f1_score: 0.6143 - loss: 0.4628 - recall: 0.7814
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7931 - auc: 0.8676 - f1_score: 0.6154 - loss: 0.4622 - recall: 0.7814
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7921 - auc: 0.8677 - f1_score: 0.6143 - loss: 0.4616 - recall: 0.7814
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7931 - auc: 0.8677 - f1_score: 0.6154 - loss: 0.4610 - recall: 0.7814

# %%
print(baseline_history.history.keys())
# Out:
# dict_keys(['accuracy', 'auc', 'f1_score', 'loss', 'recall'])

# %% [markdown]
# Let's visualize the performance of the model per epoch

# %%
# Helper function to visualize metrics
import matplotlib.pyplot as plt
import seaborn as sns

def visualize_metrics(history):
    metrics = list(history.history.keys())
    colors = sns.color_palette('bright', len(metrics))

    fig, axs = plt.subplots(len(metrics), figsize=(15, 10))

    for i, metric in enumerate(metrics):
        ax = axs.flatten()[i]

        ax.set_title(f"{metric.title()} per epoch")
        ax.set_xlabel('Epoch')
        ax.set_ylabel(f'{metric.title()}')

        ax.plot(range(1, len(history.history[metric]) + 1), history.history[metric], color=colors[i], lw=2)
    
    fig.suptitle("Metrics per Epoch")
    plt.tight_layout()
    plt.show()

# %%
visualize_metrics(baseline_history)

# %% [markdown]
# The metrics improve over time as expected
#
# I will now evaluate the model on the train and test set:

# %%
# Define a helper function to evaluate a model
def evaluate_model_on_test_and_train(model, X_train=X_train_scaled, y_train=y_train, X_test=X_test_scaled, y_test=y_test):
    print("Train:\n", model.evaluate(X_train, y_train, return_dict=True, verbose=False))
    print("Test:\n", model.evaluate(X_test, y_test, return_dict=True, verbose=False))
    return

evaluate_model_on_test_and_train(baseline_model)
# Out:
# Train:
#  {'accuracy': 0.7940886616706848, 'auc': 0.8681104183197021, 'f1_score': 0.6165136694908142, 'loss': 0.47126704454421997, 'recall': 0.7813953757286072}
# Test:
#  {'accuracy': 0.754023015499115, 'auc': 0.8175624012947083, 'f1_score': 0.5632652044296265, 'loss': 0.5376148223876953, 'recall': 0.75}

# %% [markdown]
# This is a decent performance. I will now apply regularization to see if it improves performance
#
# ### a) l1 regularization
#
# I will use an $ \alpha $ of 0.005

# %%
l1_model = models.Sequential()

# Add input layer
l1_model.add(layers.Input(input_shape))

# Add hidden layers with l1 regularization applied
l1_model.add(layers.Dense(50, activation='relu', kernel_regularizer=keras.regularizers.l1(0.005)))
l1_model.add(layers.Dense(25, activation='relu', kernel_regularizer=keras.regularizers.l1(0.005)))

# Add output layer
l1_model.add(layers.Dense(1, activation='sigmoid'))

# Train the model
l1_history = compile_and_fit(l1_model)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.2118 - auc: 0.5523 - f1_score: 0.3496 - loss: 1.9794 - recall: 1.0000
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2128 - auc: 0.5938 - f1_score: 0.3488 - loss: 1.9605 - recall: 0.9953
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2128 - auc: 0.6326 - f1_score: 0.3488 - loss: 1.9461 - recall: 0.9953
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7990 - auc: 0.8658 - f1_score: 0.6291 - loss: 1.5698 - recall: 0.8047
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7990 - auc: 0.8656 - f1_score: 0.6291 - loss: 1.5669 - recall: 0.8047
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7990 - auc: 0.8662 - f1_score: 0.6291 - loss: 1.5639 - recall: 0.8047
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8000 - auc: 0.8661 - f1_score: 0.6302 - loss: 1.5611 - recall: 0.8047
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7990 - auc: 0.8664 - f1_score: 0.6291 - loss: 1.5582 - recall: 0.8047
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7990 - auc: 0.8670 - f1_score: 0.6291 - loss: 1.5551 - recall: 0.8047
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8000 - auc: 0.8670 - f1_score: 0.6302 - loss: 1.5522 - recall: 0.8047
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7990 - auc: 0.8671 - f1_score: 0.6291 - loss: 1.5491 - recall: 0.8047
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7961 - auc: 0.8677 - f1_score: 0.6270 - loss: 1.5463 - recall: 0.8093
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7961 - auc: 0.8679 - f1_score: 0.6257 - loss: 1.5435 - recall: 0.8047
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7980 - auc: 0.8675 - f1_score: 0.6279 - loss: 1.5408 - recall: 0.8047
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7990 - auc: 0.8678 - f1_score: 0.6277 - loss: 1.5380 - recall: 0.8000
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8020 - auc: 0.8681 - f1_score: 0.6298 - loss: 1.5353 - recall: 0.7953
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7990 - auc: 0.8684 - f1_score: 0.6264 - loss: 1.5325 - recall: 0.7953
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8010 - auc: 0.8683 - f1_score: 0.6273 - loss: 1.5298 - recall: 0.7907
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8010 - auc: 0.8684 - f1_score: 0.6273 - loss: 1.5271 - recall: 0.7907
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8020 - auc: 0.8688 - f1_score: 0.6285 - loss: 1.5244 - recall: 0.7907
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8020 - auc: 0.8686 - f1_score: 0.6285 - loss: 1.5218 - recall: 0.7907
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7980 - auc: 0.8688 - f1_score: 0.6252 - loss: 1.5190 - recall: 0.7953
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7980 - auc: 0.8691 - f1_score: 0.6252 - loss: 1.5165 - recall: 0.7953
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7990 - auc: 0.8689 - f1_score: 0.6264 - loss: 1.5138 - recall: 0.7953
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7970 - auc: 0.8692 - f1_score: 0.6241 - loss: 1.5112 - recall: 0.7953
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7980 - auc: 0.8691 - f1_score: 0.6252 - loss: 1.5086 - recall: 0.7953
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7970 - auc: 0.8691 - f1_score: 0.6241 - loss: 1.5062 - recall: 0.7953
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7990 - auc: 0.8691 - f1_score: 0.6250 - loss: 1.5035 - recall: 0.7907
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7970 - auc: 0.8694 - f1_score: 0.6227 - loss: 1.5010 - recall: 0.7907
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7980 - auc: 0.8696 - f1_score: 0.6239 - loss: 1.4984 - recall: 0.7907
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7980 - auc: 0.8696 - f1_score: 0.6239 - loss: 1.4958 - recall: 0.7907

# %% [markdown]
# Visualizing metric performance:

# %%
visualize_metrics(l1_history)

# %% [markdown]
# The recall appears to be fluctuating.
#
# Evaluating on train and test set:

# %%
print("Baseline:")
evaluate_model_on_test_and_train(baseline_model)
print("\n")
print("l1 model:")
evaluate_model_on_test_and_train(l1_model)
# Out:
# Baseline:
# Train:
#  {'accuracy': 0.7940886616706848, 'auc': 0.8681104183197021, 'f1_score': 0.6165136694908142, 'loss': 0.47126704454421997, 'recall': 0.7813953757286072}
# Test:
#  {'accuracy': 0.754023015499115, 'auc': 0.8175624012947083, 'f1_score': 0.5632652044296265, 'loss': 0.5376148223876953, 'recall': 0.75}
#
#
# l1 model:
# Train:
#  {'accuracy': 0.7980295419692993, 'auc': 0.869962215423584, 'f1_score': 0.626593828201294, 'loss': 1.5099462270736694, 'recall': 0.800000011920929}
# Test:
#  {'accuracy': 0.7632184028625488, 'auc': 0.8158036470413208, 'f1_score': 0.5761316418647766, 'loss': 1.5726126432418823, 'recall': 0.760869562625885}

# %% [markdown]
# The l1 model appears to have comparable performance to the baseline (except for probably a much lower recall score).
#
# > **NB**: The model comparison might seem different for you. This is because of underlying randomization in the initialisation of the kernel weights.
#
# ### b) l2 regularization

# %%
l2_model = models.Sequential()

# Add input layer
l2_model.add(layers.Input(input_shape))

# Add hidden layers
l2_model.add(layers.Dense(50, activation='relu', kernel_regularizer=keras.regularizers.l2
#
#
# l2 model:
# Train:
#  {'accuracy': 0.7822660207748413, 'auc': 0.8651307821273804, 'f1_score': 0.614310622215271, 'loss': 0.6870522499084473, 'recall': 0.8186046481132507}
# Test:
#  {'accuracy': 0.7701149582862854, 'auc': 0.8229497075080872, 'f1_score': 0.5967741012573242, 'loss': 0.7350598573684692, 'recall': 0.804347813129425}

# %% [markdown]
# The l2 model has better recall and auc score compared to baseline.
#
# ### c) Dropout Regularization
#
# I will use a dropout rate of 0.3

# %%
dropout_model = models.Sequential()

# Add input layer
dropout_model.add(layers.Input(input_shape))
## I will not add dropout to the input layer given that the data is not substantive

# Add hidden layers and include dropout. Use a seed for reproducibility
dropout_model.add(layers.Dense(50, activation='relu'))
dropout_model.add(layers.Dropout(0.3, seed=2026))
dropout_model.add(layers.Dense(25, activation='relu'))
dropout_model.add(layers.Dropout(0.3, seed=2026))

# Add output layer
dropout_model.add(layers.Dense(1, activation='sigmoid'))

# Compile and fit the model
dropout_history = compile_and_fit(dropout_model)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6443 - auc: 0.5163 - f1_score: 0.2823 - loss: 0.7277 - recall: 0.3302
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6335 - auc: 0.5659 - f1_score: 0.3309 - loss: 0.7031 - recall: 0.4279
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6463 - auc: 0.6330 - f1_score: 0.3926 - loss: 0.6755 - recall: 0.5395
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6305 - auc: 0.6159 - f1_score: 0.3760 - loss: 0.6782 - recall: 0.5256
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6296 - auc: 0.6308 - f1_score: 0.3733 - loss: 0.6680 - recall: 0.5209
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6443 - auc: 0.6581 - f1_score: 0.4013 - loss: 0.6577 - recall: 0.5628
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6236 - auc: 0.6536 - f1_score: 0.4159 - loss: 0.6629 - recall: 0.6326
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6374 - auc: 0.6611 - f1_score: 0.4121 - loss: 0.6507 - recall: 0.6000
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6532 - auc: 0.6906 - f1_score: 0.4286 - loss: 0.6384 - recall: 0.6140
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6365 - auc: 0.6839 - f1_score: 0.4207 - loss: 0.6462 - recall: 0.6233
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6493 - auc: 0.7226 - f1_score: 0.4590 - loss: 0.6291 - recall: 0.7023
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6709 - auc: 0.7184 - f1_score: 0.4715 - loss: 0.6307 - recall: 0.6930
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6847 - auc: 0.7402 - f1_score: 0.4888 - loss: 0.6191 - recall: 0.7116
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6690 - auc: 0.7461 - f1_score: 0.4750 - loss: 0.6175 - recall: 0.7070
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6571 - auc: 0.7222 - f1_score: 0.4528 - loss: 0.6236 - recall: 0.6698
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6759 - auc: 0.7512 - f1_score: 0.4769 - loss: 0.6082 - recall: 0.6977
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6650 - auc: 0.7286 - f1_score: 0.4637 - loss: 0.6193 - recall: 0.6837
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6700 - auc: 0.7495 - f1_score: 0.4806 - loss: 0.6064 - recall: 0.7209
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6916 - auc: 0.7728 - f1_score: 0.5024 - loss: 0.5964 - recall: 0.7349
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6877 - auc: 0.7727 - f1_score: 0.5008 - loss: 0.5973 - recall: 0.7395
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6975 - auc: 0.7753 - f1_score: 0.5008 - loss: 0.5928 - recall: 0.7163
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6768 - auc: 0.7811 - f1_score: 0.4923 - loss: 0.5848 - recall: 0.7395
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6916 - auc: 0.7883 - f1_score: 0.5207 - loss: 0.5905 - recall: 0.7907
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7813 - auc: 0.8463 - f1_score: 0.5964 - loss: 0.4978 - recall: 0.7628
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7842 - auc: 0.8565 - f1_score: 0.6138 - loss: 0.4840 - recall: 0.8093
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7793 - auc: 0.8543 - f1_score: 0.6014 - loss: 0.4863 - recall: 0.7860
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7803 - auc: 0.8468 - f1_score: 0.6081 - loss: 0.5003 - recall: 0.8047
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7872 - auc: 0.8566 - f1_score: 0.6157 - loss: 0.4884 - recall: 0.8047
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7803 - auc: 0.8546 - f1_score: 0.5996 - loss: 0.4863 - recall: 0.7767
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7764 - auc: 0.8548 - f1_score: 0.5982 - loss: 0.4900 - recall: 0.7860
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7833 - auc: 0.8529 - f1_score: 0.6071 - loss: 0.4908 - recall: 0.7907
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7744 - auc: 0.8474 - f1_score: 0.5947 - loss: 0.4978 - recall: 0.7814

# %%
visualize_metrics(dropout_history)

# %% [markdown]
# There is a step-wise improvement in the metrics.

# %%
print("Baseline:")
evaluate_model_on_test_and_train(baseline_model)
print("\n\n")
print("l1 model:")
evaluate_model_on_test_and_train(l1_model)
print("\n\n")
print("l2 model:")
evaluate_model_on_test_and_train(l2_model)
print("\n\n")
print("Dropout model:")
evaluate_model_on_test_and_train(dropout_model)
# Out:
# Baseline:
# Train:
#  {'accuracy': 0.7940886616706848, 'auc': 0.8681104183197021, 'f1_score': 0.6165136694908142, 'loss': 0.47126704454421997, 'recall': 0.7813953757286072}
# Test:
#  {'accuracy': 0.754023015499115, 'auc': 0.8175624012947083, 'f1_score': 0.5632652044296265, 'loss': 0.5376148223876953, 'recall': 0.75}
#
#
#
# l1 model:
# Train:
#  {'accuracy': 0.7980295419692993, 'auc': 0.869962215423584, 'f1_score': 0.626593828201294, 'loss': 1.5099462270736694, 'recall': 0.800000011920929}
# Test:
#  {'accuracy': 0.7632184028625488, 'auc': 0.8158036470413208, 'f1_score': 0.5761316418647766, 'loss': 1.5726126432418823, 'recall': 0.760869562625885}
#
#
#
# l2 model:
# Train:
#  {'accuracy': 0.7822660207748413, 'auc': 0.8651307821273804, 'f1_score': 0.614310622215271, 'loss': 0.6870522499084473, 'recall': 0.8186046481132507}
# Test:
#  {'accuracy': 0.7701149582862854, 'auc': 0.8229497075080872, 'f1_score': 0.5967741012573242, 'loss': 0.7350598573684692, 'recall': 0.804347813129425}
#
#
#
# Dropout model:
# Train:
#  {'accuracy': 0.7950738668441772, 'auc': 0.8768662810325623, 'f1_score': 0.6338027119636536, 'loss': 0.4788336455821991, 'recall': 0.8372092843055725}
# Test:
#  {'accuracy': 0.7701149582862854, 'auc': 0.830380916595459, 'f1_score': 0.5867767930030823, 'loss': 0.5333907008171082, 'recall': 0.77173912525177}

# %% [markdown]
# The dropout model has better recall compared to the baseline model. It's performance is comparable to the l2 model, although it exhibits a much better loss metric.
#
# Finally, I will implement early stopping to the baseline model
#
# ### d) Early Stopping
#
# I will stop minimizing the loss a.k.a stop gradient descent once the f1_score stops improving

# %%
from keras.callbacks import EarlyStopping

callback = EarlyStopping(
    monitor='f1_score',
    mode='max',
    restore_best_weights=True,
    patience=5
)

early_stopping_model = models.Sequential()

# Add input layer
early_stopping_model.add(layers.Input(input_shape))

# Add hidden layers
early_stopping_model.add(layers.Dense(50, activation='relu'))
early_stopping_model.add(layers.Dense(25, activation='relu'))

# Add output layer
early_stopping_model.add(layers.Dense(1, activation='sigmoid'))

# Compile and fit the model
early_stopping_history = compile_and_fit(early_stopping_model, early_stopping=True, callbacks=[callback])
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6759 - auc: 0.7036 - f1_score: 0.4562 - loss: 0.6482 - recall: 0.6419
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7882 - auc: 0.8554 - f1_score: 0.6069 - loss: 0.5153 - recall: 0.7721
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7862 - auc: 0.8566 - f1_score: 0.6062 - loss: 0.5134 - recall: 0.7767
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7901 - auc: 0.8576 - f1_score: 0.6092 - loss: 0.5117 - recall: 0.7721
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7911 - auc: 0.8581 - f1_score: 0.6103 - loss: 0.5102 - recall: 0.7721
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7931 - auc: 0.8588 - f1_score: 0.6125 - loss: 0.5086 - recall: 0.7721
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7892 - auc: 0.8594 - f1_score: 0.6081 - loss: 0.5072 - recall: 0.7721
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7911 - auc: 0.8601 - f1_score: 0.6103 - loss: 0.5056 - recall: 0.7721
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7911 - auc: 0.8609 - f1_score: 0.6103 - loss: 0.5042 - recall: 0.7721
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7921 - auc: 0.8615 - f1_score: 0.6114 - loss: 0.5027 - recall: 0.7721
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7921 - auc: 0.8617 - f1_score: 0.6100 - loss: 0.5014 - recall: 0.7674

# %% [markdown]
# The f1-score stopped increasing at epoch 40 (might be different for you)

# %%
visualize_metrics(early_stopping_history)

# %% [markdown]
# ## 5. Final Evaluation

# %%
print("Baseline:")
evaluate_model_on_test_and_train(baseline_model)
print("\n")
print("l1 model:")
evaluate_model_on_test_and_train(l1_model)
print("\n")
print("l2 model:")
evaluate_model_on_test_and_train(l2_model)
print("\n")
print("Dropout model:")
evaluate_model_on_test_and_train(dropout_model)
print("\n")
print("Callback model:")
evaluate_model_on_test_and_train(early_stopping_model)
# Out:
# Baseline:
# Train:
#  {'accuracy': 0.7940886616706848, 'auc': 0.8681104183197021, 'f1_score': 0.6165136694908142, 'loss': 0.47126704454421997, 'recall': 0.7813953757286072}
# Test:
#  {'accuracy': 0.754023015499115, 'auc': 0.8175624012947083, 'f1_score': 0.5632652044296265, 'loss': 0.5376148223876953, 'recall': 0.75}
#
#
# l1 model:
# Train:
#  {'accuracy': 0.7980295419692993, 'auc': 0.869962215423584, 'f1_score': 0.626593828201294, 'loss': 1.5099462270736694, 'recall': 0.800000011920929}
# Test:
#  {'accuracy': 0.7632184028625488, 'auc': 0.8158036470413208, 'f1_score': 0.5761316418647766, 'loss': 1.5726126432418823, 'recall': 0.760869562625885}
#
#
# l2 model:
# Train:
#  {'accuracy': 0.7822660207748413, 'auc': 0.8651307821273804, 'f1_score': 0.614310622215271, 'loss': 0.6870522499084473, 'recall': 0.8186046481132507}
# Test:
#  {'accuracy': 0.7701149582862854, 'auc': 0.8229497075080872, 'f1_score': 0.5967741012573242, 'loss': 0.7350598573684692, 'recall': 0.804347813129425}
#
#
# Dropout model:
# Train:
#  {'accuracy': 0.7950738668441772, 'auc': 0.8768662810325623, 'f1_score': 0.6338027119636536, 'loss': 0.4788336455821991, 'recall': 0.8372092843055725}
# Test:
#  {'accuracy': 0.7701149582862854, 'auc': 0.830380916595459, 'f1_score': 0.5867767930030823, 'loss': 0.5333907008171082, 'recall': 0.77173912525177}
#
#
# Callback model:
# Train:
#  {'accuracy': 0.7901477813720703, 'auc': 0.859188973903656, 'f1_score': 0.6091741919517517, 'loss': 0.5396303534507751, 'recall': 0.7720929980278015}
# Test:
#  {'accuracy': 0.7724137902259827, 'auc': 0.8152173757553101, 'f1_score': 0.5787233710289001, 'loss': 0.5809147357940674, 'recall': 0.739130437374115}

# %% [markdown]
# ## 6. Conclusion
#
# The best all-round model is the **l2 model**. This is the model I shall use as the best neural network.
#
# > **NB**: The best model for you might seem different. This is because of underlying randomization in the initialisation of the kernel weights. However, after running the notebook multiple times, I found the model that performed the best consistently to be the l2 model.

# %%
l2_model.save('../best_neural_model.keras')
