# %% [markdown]
# ## 1. Import Data and EDA
#
# Descriptions of the columns are available [here](../../Data/floods_description.md)

# %%
import geopandas as gpd

df = gpd.read_file('../../Data/floods.gpkg')

df.head()
# Out:
#                      ward          subcounty  county  pop2009  flooded  \
# 0                  WABERA  Isiolo Sub County  ISIOLO  17431.0        0
# 1    North Kamagambo Ward   Rongo Sub County  Migori  18755.0        0
# 2  Central Kamagambo Ward   Rongo Sub County  Migori  27756.0        0
# 3    South Kamagambo Ward   Rongo Sub County  Migori  27179.0        0
# 4        North Sakwa Ward  Awendo Sub County  Migori  22874.0        0
#
#    rain_cumulative_mm  rain_max_daily_mm  rain_preflood_7d_mm  \
# 0            0.000000           0.000000             0.000000
# 1          258.608840          14.135786            39.955728
# 2          125.951383           8.779010            20.537484
# 3           45.941367           5.696220            10.762588
# 4           78.351185           4.580237            10.795914
#
#    elevation_mean_m  elevation_min_m  elevation_max_m  slope_mean_deg  \
# 0       1099.219448           1026.0           1177.0        1.413028
# 1       1405.549444           1350.0           1508.0        2.246821
# 2       1462.532567           1387.0           1534.0        3.392240
# 3       1490.546337           1363.0           1638.0        4.263301
# 4       1376.935386           1287.0           1617.0        3.834336
#
#                                             geometry
# 0  MULTIPOLYGON (((37.59968 0.40029, 37.59976 0.4...
# 1  MULTIPOLYGON (((34.59938 -0.65054, 34.60006 -0...
# 2  MULTIPOLYGON (((34.61175 -0.73357, 34.61183 -0...
# 3  MULTIPOLYGON (((34.61751 -0.87293, 34.6175 -0....
# 4  MULTIPOLYGON (((34.55349 -0.75193, 34.55364 -0...

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ward                 1450 non-null   object
#  1   subcounty            1450 non-null   object
#  2   county               1450 non-null   object
#  3   pop2009              1450 non-null   float64
#  4   flooded              1450 non-null   int64
#  5   rain_cumulative_mm   1450 non-null   float64
#  6   rain_max_daily_mm    1450 non-null   float64
#  7   rain_preflood_7d_mm  1450 non-null   float64
#  8   elevation_mean_m     1450 non-null   float64
#  9   elevation_min_m      1450 non-null   float64
#  10  elevation_max_m      1450 non-null   float64
#  11  slope_mean_deg       1450 non-null   float64
#  12  geometry             1450 non-null   geometry
# dtypes: float64(8), geometry(1), int64(1), object(3)
# memory usage: 147.4+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 2. Create features and target
#
# I will engineer a new feature: `elevation_range_m`, that is the difference between the maximum (`elevation_max_m`) and minimum (`elevation_min_m`) elevations. This is important because places with steeper slopes i.e. greater elevation ranges tend to flood less compared to flat areas with lower elevation ranges.

# %%
df['elevation_range_m'] = df['elevation_max_m'] - df['elevation_min_m']

df.head()
# Out:
#                      ward          subcounty  county  pop2009  flooded  \
# 0                  WABERA  Isiolo Sub County  ISIOLO  17431.0        0
# 1    North Kamagambo Ward   Rongo Sub County  Migori  18755.0        0
# 2  Central Kamagambo Ward   Rongo Sub County  Migori  27756.0        0
# 3    South Kamagambo Ward   Rongo Sub County  Migori  27179.0        0
# 4        North Sakwa Ward  Awendo Sub County  Migori  22874.0        0
#
#    rain_cumulative_mm  rain_max_daily_mm  rain_preflood_7d_mm  \
# 0            0.000000           0.000000             0.000000
# 1          258.608840          14.135786            39.955728
# 2          125.951383           8.779010            20.537484
# 3           45.941367           5.696220            10.762588
# 4           78.351185           4.580237            10.795914
#
#    elevation_mean_m  elevation_min_m  elevation_max_m  slope_mean_deg  \
# 0       1099.219448           1026.0           1177.0        1.413028
# 1       1405.549444           1350.0           1508.0        2.246821
# 2       1462.532567           1387.0           1534.0        3.392240
# 3       1490.546337           1363.0           1638.0        4.263301
# 4       1376.935386           1287.0           1617.0        3.834336
#
#                                             geometry  elevation_range_m
# 0  MULTIPOLYGON (((37.59968 0.40029, 37.59976 0.4...              151.0
# 1  MULTIPOLYGON (((34.59938 -0.65054, 34.60006 -0...              158.0
# 2  MULTIPOLYGON (((34.61175 -0.73357, 34.61183 -0...              147.0
# 3  MULTIPOLYGON (((34.61751 -0.87293, 34.6175 -0....              275.0
# 4  MULTIPOLYGON (((34.55349 -0.75193, 34.55364 -0...              330.0

# %%
df.columns
# Out:
# Index(['ward', 'subcounty', 'county', 'pop2009', 'flooded',
#        'rain_cumulative_mm', 'rain_max_daily_mm', 'rain_preflood_7d_mm',
#        'elevation_mean_m', 'elevation_min_m', 'elevation_max_m',
#        'slope_mean_deg', 'geometry', 'elevation_range_m'],
#       dtype='object')

# %%
# Drop geometry and metadata columns
feature_columns = [
    'pop2009',
    'rain_cumulative_mm',
    'rain_max_daily_mm',
    'rain_preflood_7d_mm',
    'elevation_mean_m',
    'elevation_min_m',
    'elevation_max_m',
    'elevation_range_m',
    'slope_mean_deg'
]

target_column = 'flooded'

# Features
X = df[feature_columns]
y = df[target_column]

X.head()
# Out:
#    pop2009  rain_cumulative_mm  rain_max_daily_mm  rain_preflood_7d_mm  \
# 0  17431.0            0.000000           0.000000             0.000000
# 1  18755.0          258.608840          14.135786            39.955728
# 2  27756.0          125.951383           8.779010            20.537484
# 3  27179.0           45.941367           5.696220            10.762588
# 4  22874.0           78.351185           4.580237            10.795914
#
#    elevation_mean_m  elevation_min_m  elevation_max_m  elevation_range_m  \
# 0       1099.219448           1026.0           1177.0              151.0
# 1       1405.549444           1350.0           1508.0              158.0
# 2       1462.532567           1387.0           1534.0              147.0
# 3       1490.546337           1363.0           1638.0              275.0
# 4       1376.935386           1287.0           1617.0              330.0
#
#    slope_mean_deg
# 0        1.413028
# 1        2.246821
# 2        3.392240
# 3        4.263301
# 4        3.834336

# %% [markdown]
# ## 3. Preprocessing
#
# First perform standard **train-test split**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2026, stratify=y, test_size=0.3)

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1015 entries, 454 to 845
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pop2009              1015 non-null   float64
#  1   rain_cumulative_mm   1015 non-null   float64
#  2   rain_max_daily_mm    1015 non-null   float64
#  3   rain_preflood_7d_mm  1015 non-null   float64
#  4   elevation_mean_m     1015 non-null   float64
#  5   elevation_min_m      1015 non-null   float64
#  6   elevation_max_m      1015 non-null   float64
#  7   elevation_range_m    1015 non-null   float64
#  8   slope_mean_deg       1015 non-null   float64
# dtypes: float64(9)
# memory usage: 79.3 KB

# %% [markdown]
# For neural networks, standardization of the features and targets has to be done.
#
# `y` is a binary column. Thus, it does not need to be standardized

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_scaled.shape
# Out:
# (1015, 9)

# %% [markdown]
# Due to the limited size of the dataset, we will not have validation data.

# %% [markdown]
# ## 4. Modelling
#
# I will use Keras' API to build the ANN.
#
# I will ensure I use a balanced class weight to account for class imbalance
#
# I will experiment with three types of regularization to see which results in the best metrics:
#  - l1 regularization
#  - l2 regularization
#  - dropout regularization
#
# I will also build a model that implements **Early Stopping**
#
# I will start by building a baseline model that has no regularization whatsoever

# %%
# Computing class weights
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y),
    y=y
)

class_dict = dict(enumerate(class_weights))

class_dict # These are weights required to ensure the classes are handled fairly by the model
# Out:
# {0: np.float64(0.6342957130358705), 1: np.float64(2.3615635179153096)}

# %%
# Baseline model
import keras
from keras import models, layers

# Instantiate
baseline_model = models.Sequential()
input_shape = (X_train_scaled.shape[1],)

# Add input layer
baseline_model.add(layers.Input(input_shape))

# Add hidden layers
baseline_model.add(layers.Dense(50, activation='relu'))
baseline_model.add(layers.Dense(25, activation='relu'))

# Add output layer
baseline_model.add(layers.Dense(1, activation='sigmoid'))

# Define a helper function to compile and fit the model and return history
def compile_and_fit(model, X_train=X_train_scaled, y_train=y_train, class_dict=class_dict, early_stopping=False, callbacks=None, n_epochs=100):
    # Compile
    model.compile(
        optimizer='sgd',
        loss='binary_crossentropy',
        # I will track recall, auc, f1-score and accuracy
        metrics=[
            'accuracy',
            keras.metrics.Recall(name='recall'),
            keras.metrics.AUC(name='auc'),
            keras.metrics.F1Score(threshold=0.5, average='micro')
        ]
    )

    # Fit the model
    if early_stopping:
        history = model.fit(
            X_train,
            y_train,
            epochs=n_epochs,
            batch_size=200,
            class_weight=class_dict,
            callbacks=callbacks
        )
    else:
        history = model.fit(
            X_train,
            y_train,
            epochs=n_epochs,
            batch_size=200,
            class_weight=class_dict
        )

    # Return model training history
    return history
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778661062.909945  512886 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# W0000 00:00:1778661067.135925  513006 cuda_executor.cc:1755] Failed to determine cuDNN version (Note that this is expected if the application doesn't link the cuDNN plugin): INTERNAL: cuDNN error: CUDNN_STATUS_INTERNAL_ERROR
# W0000 00:00:1778661067.248420  512886 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
baseline_history = compile_and_fit(baseline_model)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.2394 - auc: 0.6426 - f1_score: 0.3480 - loss: 0.7015 - recall: 0.9581
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2512 - auc: 0.6688 - f1_score: 0.3493 - loss: 0.6879 - recall: 0.9488
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2828 - auc: 0.6962 - f1_score: 0.3592 - loss: 0.6756 - recall: 0.9488
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3389 - auc: 0.7195 - f1_score: 0.3770 - loss: 0.6648 - recall: 0.9442
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4049 - auc: 0.7404 - f1_score: 0.4008 - loss: 0.6544 - recall: 0.9395
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4433 - auc: 0.7570 - f1_score: 0.4145 - loss: 0.6452 - recall: 0.9302
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5025 - auc: 0.7695 - f1_score: 0.4395 - loss: 0.6371 - recall: 0.9209
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5438 - auc: 0.7813 - f1_score: 0.4610 - loss: 0.6293 - recall: 0.9209
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5842 - auc: 0.7912 - f1_score: 0.4841 - loss: 0.6220 - recall: 0.9209
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6030 - auc: 0.7998 - f1_score: 0.4905 - loss: 0.6153 - recall: 0.9023
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6256 - auc: 0.8071 - f1_score: 0.5052 - loss: 0.6090 - recall: 0.9023
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6532 - auc: 0.8130 - f1_score: 0.5217 - loss: 0.6027 - recall: 0.8930
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6631 - auc: 0.8188 - f1_score: 0.5250 - loss: 0.5970 - recall: 0.8791
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6847 - auc: 0.8238 - f1_score: 0.5402 - loss: 0.5910 - recall: 0.8744
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6877 - auc: 0.8286 - f1_score: 0.5426 - loss: 0.5861 - recall: 0.8744
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8000 - auc: 0.8722 - f1_score: 0.6262 - loss: 0.4596 - recall: 0.7907
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8000 - auc: 0.8722 - f1_score: 0.6262 - loss: 0.4591 - recall: 0.7907
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8000 - auc: 0.8722 - f1_score: 0.6248 - loss: 0.4586 - recall: 0.7860
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7990 - auc: 0.8723 - f1_score: 0.6236 - loss: 0.4582 - recall: 0.7860
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8000 - auc: 0.8726 - f1_score: 0.6262 - loss: 0.4576 - recall: 0.7907
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8000 - auc: 0.8726 - f1_score: 0.6262 - loss: 0.4572 - recall: 0.7907
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8010 - auc: 0.8729 - f1_score: 0.6259 - loss: 0.4568 - recall: 0.7860
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8000 - auc: 0.8729 - f1_score: 0.6248 - loss: 0.4563 - recall: 0.7860
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8020 - auc: 0.8731 - f1_score: 0.6271 - loss: 0.4558 - recall: 0.7860
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8010 - auc: 0.8731 - f1_score: 0.6259 - loss: 0.4553 - recall: 0.7860

# %%
print(baseline_history.history.keys())
# Out:
# dict_keys(['accuracy', 'auc', 'f1_score', 'loss', 'recall'])

# %% [markdown]
# Let's visualize the performance of the model per epoch

# %%
# Helper function to visualize metrics
import matplotlib.pyplot as plt
import seaborn as sns

def visualize_metrics(history):
    metrics = list(history.history.keys())
    colors = sns.color_palette('bright', len(metrics))

    fig, axs = plt.subplots(len(metrics), figsize=(15, 10))

    for i, metric in enumerate(metrics):
        ax = axs.flatten()[i]

        ax.set_title(f"{metric.title()} per epoch")
        ax.set_xlabel('Epoch')
        ax.set_ylabel(f'{metric.title()}')

        ax.plot(range(1, len(history.history[metric]) + 1), history.history[metric], color=colors[i], lw=2)
    
    fig.suptitle("Metrics per Epoch")
    plt.tight_layout()
    plt.show()

# %%
visualize_metrics(baseline_history)

# %% [markdown]
# The metrics improve over time as expected
#
# I will now evaluate the model on the train and test set:

# %%
# Define a helper function to evaluate a model
def evaluate_model_on_test_and_train(model, X_train=X_train_scaled, y_train=y_train, X_test=X_test_scaled, y_test=y_test):
    print("Train:\n", model.evaluate(X_train, y_train, return_dict=True, verbose=False))
    print("Test:\n", model.evaluate(X_test, y_test, return_dict=True, verbose=False))
    return

evaluate_model_on_test_and_train(baseline_model)
# Out:
# Train:
#  {'accuracy': 0.8009852170944214, 'auc': 0.8734215497970581, 'f1_score': 0.6273062229156494, 'loss': 0.4702621102333069, 'recall': 0.7906976938247681}
# Test:
#  {'accuracy': 0.7701149582862854, 'auc': 0.8209215402603149, 'f1_score': 0.5798318386077881, 'loss': 0.5447466373443604, 'recall': 0.75}

# %% [markdown]
# This is a decent performance. I will now apply regularization to see if it improves performance
#
# ### a) l1 regularization
#
# I will use an $ \alpha $ of 0.005

# %%
l1_model = models.Sequential()

# Add input layer
l1_model.add(layers.Input(input_shape))

# Add hidden layers with l1 regularization applied
l1_model.add(layers.Dense(50, activation='relu', kernel_regularizer=keras.regularizers.l1(0.005)))
l1_model.add(layers.Dense(25, activation='relu', kernel_regularizer=keras.regularizers.l1(0.005)))

# Add output layer
l1_model.add(layers.Dense(1, activation='sigmoid'))

# Train the model
l1_history = compile_and_fit(l1_model)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2355 - auc: 0.6276 - f1_score: 0.3501 - loss: 1.9473 - recall: 0.9721
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2483 - auc: 0.6474 - f1_score: 0.3528 - loss: 1.9387 - recall: 0.9674
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2611 - auc: 0.6686 - f1_score: 0.3568 - loss: 1.9299 - recall: 0.9674
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8069 - auc: 0.8672 - f1_score: 0.6231 - loss: 1.5956 - recall: 0.7535
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8069 - auc: 0.8674 - f1_score: 0.6231 - loss: 1.5925 - recall: 0.7535
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8069 - auc: 0.8674 - f1_score: 0.6187 - loss: 1.5894 - recall: 0.7395
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8079 - auc: 0.8674 - f1_score: 0.6199 - loss: 1.5865 - recall: 0.7395
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8069 - auc: 0.8678 - f1_score: 0.6187 - loss: 1.5835 - recall: 0.7395
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8059 - auc: 0.8681 - f1_score: 0.6190 - loss: 1.5805 - recall: 0.7442
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8069 - auc: 0.8680 - f1_score: 0.6172 - loss: 1.5775 - recall: 0.7349
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8059 - auc: 0.8679 - f1_score: 0.6160 - loss: 1.5745 - recall: 0.7349
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8059 - auc: 0.8682 - f1_score: 0.6160 - loss: 1.5715 - recall: 0.7349
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8059 - auc: 0.8685 - f1_score: 0.6175 - loss: 1.5685 - recall: 0.7395
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8079 - auc: 0.8685 - f1_score: 0.6184 - loss: 1.5656 - recall: 0.7349
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8079 - auc: 0.8684 - f1_score: 0.6169 - loss: 1.5626 - recall: 0.7302
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8079 - auc: 0.8687 - f1_score: 0.6169 - loss: 1.5597 - recall: 0.7302
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8069 - auc: 0.8691 - f1_score: 0.6172 - loss: 1.5567 - recall: 0.7349
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8079 - auc: 0.8688 - f1_score: 0.6184 - loss: 1.5538 - recall: 0.7349
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8079 - auc: 0.8692 - f1_score: 0.6199 - loss: 1.5510 - recall: 0.7395
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8099 - auc: 0.8694 - f1_score: 0.6267 - loss: 1.5482 - recall: 0.7535
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8089 - auc: 0.8693 - f1_score: 0.6240 - loss: 1.5454 - recall: 0.7488
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8089 - auc: 0.8693 - f1_score: 0.6226 - loss: 1.5426 - recall: 0.7442
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8079 - auc: 0.8697 - f1_score: 0.6199 - loss: 1.5399 - recall: 0.7395
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8089 - auc: 0.8696 - f1_score: 0.6211 - loss: 1.5371 - recall: 0.7395
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8089 - auc: 0.8696 - f1_score: 0.6226 - loss: 1.5344 - recall: 0.7442
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8099 - auc: 0.8701 - f1_score: 0.6252 - loss: 1.5316 - recall: 0.7488
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8089 - auc: 0.8702 - f1_score: 0.6240 - loss: 1.5288 - recall: 0.7488
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8099 - auc: 0.8700 - f1_score: 0.6252 - loss: 1.5261 - recall: 0.7488
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8089 - auc: 0.8701 - f1_score: 0.6240 - loss: 1.5233 - recall: 0.7488

# %% [markdown]
# Visualizing metric performance:

# %%
visualize_metrics(l1_history)

# %% [markdown]
# The recall appears to be fluctuating.
#
# Evaluating on train and test set:

# %%
print("Baseline:")
evaluate_model_on_test_and_train(baseline_model)
print("\n")
print("l1 model:")
evaluate_model_on_test_and_train(l1_model)
# Out:
# Baseline:
# Train:
#  {'accuracy': 0.8009852170944214, 'auc': 0.8734215497970581, 'f1_score': 0.6273062229156494, 'loss': 0.4702621102333069, 'recall': 0.7906976938247681}
# Test:
#  {'accuracy': 0.7701149582862854, 'auc': 0.8209215402603149, 'f1_score': 0.5798318386077881, 'loss': 0.5447466373443604, 'recall': 0.75}
#
#
# l1 model:
# Train:
#  {'accuracy': 0.8088669776916504, 'auc': 0.870084285736084, 'f1_score': 0.6240309476852417, 'loss': 1.5443994998931885, 'recall': 0.7488372325897217}
# Test:
#  {'accuracy': 0.7586206793785095, 'auc': 0.8110026717185974, 'f1_score': 0.5374448895454407, 'loss': 1.6156351566314697, 'recall': 0.6630434989929199}

# %% [markdown]
# The l1 model appears to have comparable performance to the baseline (except for probably a much lower recall score).
#
# > **NB**: The model comparison might seem different for you. This is because of underlying randomization in the initialisation of the kernel weights.
#
# ### b) l2 regularization

# %%
l2_model = models.Sequential()

# Add input layer
l2_model.add(layers.Input(input_shape))

# Add hidden layers
l2_model.add(layers.Dense(50, activation='relu', kernel_regularizer
#
#
# l2 model:
# Train:
#  {'accuracy': 0.7891625761985779, 'auc': 0.8674970865249634, 'f1_score': 0.6178570985794067, 'loss': 0.703395426273346, 'recall': 0.804651141166687}
# Test:
#  {'accuracy': 0.7655172348022461, 'auc': 0.8242806196212769, 'f1_score': 0.5749999284744263, 'loss': 0.7599907517433167, 'recall': 0.75}

# %% [markdown]
# The l2 model has better recall and auc score compared to baseline.
#
# ### c) Dropout Regularization
#
# I will use a dropout rate of 0.3

# %%
dropout_model = models.Sequential()

# Add input layer
dropout_model.add(layers.Input(input_shape))
## I will not add dropout to the input layer given that the data is not substantive

# Add hidden layers and include dropout. Use a seed for reproducibility
dropout_model.add(layers.Dense(50, activation='relu'))
dropout_model.add(layers.Dropout(0.3, seed=2026))
dropout_model.add(layers.Dense(25, activation='relu'))
dropout_model.add(layers.Dropout(0.3, seed=2026))

# Add output layer
dropout_model.add(layers.Dense(1, activation='sigmoid'))

# Compile and fit the model
dropout_history = compile_and_fit(dropout_model)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3458 - auc: 0.4743 - f1_score: 0.3293 - loss: 0.7753 - recall: 0.7581
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3616 - auc: 0.5569 - f1_score: 0.3468 - loss: 0.7368 - recall: 0.8000
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3754 - auc: 0.5998 - f1_score: 0.3517 - loss: 0.7180 - recall: 0.8000
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3813 - auc: 0.5955 - f1_score: 0.3499 - loss: 0.7083 - recall: 0.7860
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4059 - auc: 0.6036 - f1_score: 0.3712 - loss: 0.7060 - recall: 0.8279
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4197 - auc: 0.6200 - f1_score: 0.3660 - loss: 0.6930 - recall: 0.7907
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4463 - auc: 0.6268 - f1_score: 0.3811 - loss: 0.6935 - recall: 0.8047
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4581 - auc: 0.6621 - f1_score: 0.3982 - loss: 0.6749 - recall: 0.8465
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4759 - auc: 0.6426 - f1_score: 0.3941 - loss: 0.6834 - recall: 0.8047
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4818 - auc: 0.6653 - f1_score: 0.3954 - loss: 0.6723 - recall: 0.8000
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5054 - auc: 0.6918 - f1_score: 0.4230 - loss: 0.6662 - recall: 0.8558
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4897 - auc: 0.6710 - f1_score: 0.3949 - loss: 0.6664 - recall: 0.7860
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4926 - auc: 0.7039 - f1_score: 0.4032 - loss: 0.6506 - recall: 0.8093
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5517 - auc: 0.7268 - f1_score: 0.4431 - loss: 0.6359 - recall: 0.8419
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5527 - auc: 0.7064 - f1_score: 0.4339 - loss: 0.6498 - recall: 0.8093
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5537 - auc: 0.7422 - f1_score: 0.4522 - loss: 0.6353 - recall: 0.8698
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5852 - auc: 0.7514 - f1_score: 0.4704 - loss: 0.6308 - recall: 0.8698
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5852 - auc: 0.7499 - f1_score: 0.4637 - loss: 0.6286 - recall: 0.8465
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6010 - auc: 0.7330 - f1_score: 0.4534 - loss: 0.6224 - recall: 0.7814
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6049 - auc: 0.7479 - f1_score: 0.4646 - loss: 0.6160 - recall: 0.8093
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6148 - auc: 0.7555 - f1_score: 0.4607 - loss: 0.6144 - recall: 0.7767
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6000 - auc: 0.7462 - f1_score: 0.4587 - loss: 0.6227 - recall: 0.8000
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6345 - auc: 0.7699 - f1_score: 0.4854 - loss: 0.6013 - recall: 0.8140
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6374 - auc: 0.7605 - f1_score: 0.4758 - loss: 0.6123 - recall: 0.7767
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6473 - auc: 0.7804 - f1_score: 0.4841 - loss: 0.5900 - recall: 0.7814
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7882 - auc: 0.8462 - f1_score: 0.6055 - loss: 0.4986 - recall: 0.7674
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7961 - auc: 0.8405 - f1_score: 0.6174 - loss: 0.5129 - recall: 0.7767
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7803 - auc: 0.8427 - f1_score: 0.5923 - loss: 0.5036 - recall: 0.7535
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7793 - auc: 0.8418 - f1_score: 0.5882 - loss: 0.5099 - recall: 0.7442
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7872 - auc: 0.8511 - f1_score: 0.6029 - loss: 0.5034 - recall: 0.7628
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7813 - auc: 0.8388 - f1_score: 0.5858 - loss: 0.5120 - recall: 0.7302
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7744 - auc: 0.8497 - f1_score: 0.5751 - loss: 0.4983 - recall: 0.7209

# %%
visualize_metrics(dropout_history)

# %% [markdown]
# There is a step-wise improvement in the metrics.

# %%
print("Baseline:")
evaluate_model_on_test_and_train(baseline_model)
print("\n\n")
print("l1 model:")
evaluate_model_on_test_and_train(l1_model)
print("\n\n")
print("l2 model:")
evaluate_model_on_test_and_train(l2_model)
print("\n\n")
print("Dropout model:")
evaluate_model_on_test_and_train(dropout_model)
# Out:
# Baseline:
# Train:
#  {'accuracy': 0.8009852170944214, 'auc': 0.8734215497970581, 'f1_score': 0.6273062229156494, 'loss': 0.4702621102333069, 'recall': 0.7906976938247681}
# Test:
#  {'accuracy': 0.7701149582862854, 'auc': 0.8209215402603149, 'f1_score': 0.5798318386077881, 'loss': 0.5447466373443604, 'recall': 0.75}
#
#
#
# l1 model:
# Train:
#  {'accuracy': 0.8088669776916504, 'auc': 0.870084285736084, 'f1_score': 0.6240309476852417, 'loss': 1.5443994998931885, 'recall': 0.7488372325897217}
# Test:
#  {'accuracy': 0.7586206793785095, 'auc': 0.8110026717185974, 'f1_score': 0.5374448895454407, 'loss': 1.6156351566314697, 'recall': 0.6630434989929199}
#
#
#
# l2 model:
# Train:
#  {'accuracy': 0.7891625761985779, 'auc': 0.8674970865249634, 'f1_score': 0.6178570985794067, 'loss': 0.703395426273346, 'recall': 0.804651141166687}
# Test:
#  {'accuracy': 0.7655172348022461, 'auc': 0.8242806196212769, 'f1_score': 0.5749999284744263, 'loss': 0.7599907517433167, 'recall': 0.75}
#
#
#
# Dropout model:
# Train:
#  {'accuracy': 0.8118226528167725, 'auc': 0.868834376335144, 'f1_score': 0.631984531879425, 'loss': 0.4692893922328949, 'recall': 0.7627906799316406}
# Test:
#  {'accuracy': 0.7609195113182068, 'auc': 0.818861722946167, 'f1_score': 0.5517240762710571, 'loss': 0.5251023769378662, 'recall': 0.695652186870575}

# %% [markdown]
# The dropout model has better recall compared to the baseline model. It's performance is comparable to the l2 model, although it exhibits a much better loss metric.
#
# Finally, I will implement early stopping to the baseline model
#
# ### d) Early Stopping
#
# I will stop minimizing the loss a.k.a stop gradient descent once the f1_score stops improving

# %%
from keras.callbacks import EarlyStopping

callback = EarlyStopping(
    monitor='f1_score',
    mode='max',
    restore_best_weights=True,
    patience=5
)

early_stopping_model = models.Sequential()

# Add input layer
early_stopping_model.add(layers.Input(input_shape))

# Add hidden layers
early_stopping_model.add(layers.Dense(50, activation='relu'))
early_stopping_model.add(layers.Dense(25, activation='relu'))

# Add output layer
early_stopping_model.add(layers.Dense(1, activation='sigmoid'))

# Compile and fit the model
early_stopping_history = compile_and_fit(early_stopping_model, early_stopping=True, callbacks=[callback])
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6404 - auc: 0.7459 - f1_score: 0.4624 - loss: 0.6300 - recall: 0.7302
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6650 - auc: 0.7655 - f1_score: 0.4880 - loss: 0.6190 - recall: 0.7535
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6719 - auc: 0.7821 - f1_score: 0.4947 - loss: 0.6079 - recall: 0.7581
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7892 - auc: 0.8610 - f1_score: 0.6179 - loss: 0.4842 - recall: 0.8047
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7892 - auc: 0.8613 - f1_score: 0.6151 - loss: 0.4829 - recall: 0.7953
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7882 - auc: 0.8615 - f1_score: 0.6126 - loss: 0.4816 - recall: 0.7907
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7892 - auc: 0.8620 - f1_score: 0.6137 - loss: 0.4807 - recall: 0.7907
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7901 - auc: 0.8620 - f1_score: 0.6162 - loss: 0.4797 - recall: 0.7953
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7901 - auc: 0.8624 - f1_score: 0.6162 - loss: 0.4787 - recall: 0.7953

# %% [markdown]
# The f1-score stopped increasing at epoch 40 (might be different for you)

# %%
visualize_metrics(early_stopping_history)

# %% [markdown]
# ## 5. Final Evaluation

# %%
print("Baseline:")
evaluate_model_on_test_and_train(baseline_model)
print("\n")
print("l1 model:")
evaluate_model_on_test_and_train(l1_model)
print("\n")
print("l2 model:")
evaluate_model_on_test_and_train(l2_model)
print("\n")
print("Dropout model:")
evaluate_model_on_test_and_train(dropout_model)
print("\n")
print("Callback model:")
evaluate_model_on_test_and_train(early_stopping_model)
# Out:
# Baseline:
# Train:
#  {'accuracy': 0.8009852170944214, 'auc': 0.8734215497970581, 'f1_score': 0.6273062229156494, 'loss': 0.4702621102333069, 'recall': 0.7906976938247681}
# Test:
#  {'accuracy': 0.7701149582862854, 'auc': 0.8209215402603149, 'f1_score': 0.5798318386077881, 'loss': 0.5447466373443604, 'recall': 0.75}
#
#
# l1 model:
# Train:
#  {'accuracy': 0.8088669776916504, 'auc': 0.870084285736084, 'f1_score': 0.6240309476852417, 'loss': 1.5443994998931885, 'recall': 0.7488372325897217}
# Test:
#  {'accuracy': 0.7586206793785095, 'auc': 0.8110026717185974, 'f1_score': 0.5374448895454407, 'loss': 1.6156351566314697, 'recall': 0.6630434989929199}
#
#
# l2 model:
# Train:
#  {'accuracy': 0.7891625761985779, 'auc': 0.8674970865249634, 'f1_score': 0.6178570985794067, 'loss': 0.703395426273346, 'recall': 0.804651141166687}
# Test:
#  {'accuracy': 0.7655172348022461, 'auc': 0.8242806196212769, 'f1_score': 0.5749999284744263, 'loss': 0.7599907517433167, 'recall': 0.75}
#
#
# Dropout model:
# Train:
#  {'accuracy': 0.8118226528167725, 'auc': 0.868834376335144, 'f1_score': 0.631984531879425, 'loss': 0.4692893922328949, 'recall': 0.7627906799316406}
# Test:
#  {'accuracy': 0.7609195113182068, 'auc': 0.818861722946167, 'f1_score': 0.5517240762710571, 'loss': 0.5251023769378662, 'recall': 0.695652186870575}
#
#
# Callback model:
# Train:
#  {'accuracy': 0.7891625761985779, 'auc': 0.8611714839935303, 'f1_score': 0.6151078343391418, 'loss': 0.5004165172576904, 'recall': 0.7953488230705261}
# Test:
#  {'accuracy': 0.7609195113182068, 'auc': 0.8162156343460083, 'f1_score': 0.5702478289604187, 'loss': 0.5523504018783569, 'recall': 0.75}

# %% [markdown]
# ## 6. Conclusion
#
# The best all-round model is the **l2 model**. This is the model I shall use as the best neural network.
#
# > **NB**: The best model for you might seem different. This is because of underlying randomization in the initialisation of the kernel weights. However, after running the notebook multiple times, I found the model that performed the best consistently to be the l2 model.

# %%
l2_model.save('../best_neural_model.keras')
