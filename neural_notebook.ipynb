# %% [markdown]
# ## 1. Import Data and EDA
#
# Descriptions of the columns are available [here](./Data/floods_description.md)

# %%
import geopandas as gpd

df = gpd.read_file('./Data/floods.gpkg')

df.head()
# Out:
#                      ward          subcounty  county  pop2009  flooded  \
# 0                  WABERA  Isiolo Sub County  ISIOLO  17431.0        0
# 1    North Kamagambo Ward   Rongo Sub County  Migori  18755.0        0
# 2  Central Kamagambo Ward   Rongo Sub County  Migori  27756.0        0
# 3    South Kamagambo Ward   Rongo Sub County  Migori  27179.0        0
# 4        North Sakwa Ward  Awendo Sub County  Migori  22874.0        0
#
#    rain_cumulative_mm  rain_max_daily_mm  rain_preflood_7d_mm  \
# 0            0.000000           0.000000             0.000000
# 1          258.608840          14.135786            39.955728
# 2          125.951383           8.779010            20.537484
# 3           45.941367           5.696220            10.762588
# 4           78.351185           4.580237            10.795914
#
#    elevation_mean_m  elevation_min_m  elevation_max_m  slope_mean_deg  \
# 0       1099.219448           1026.0           1177.0        1.413028
# 1       1405.549444           1350.0           1508.0        2.246821
# 2       1462.532567           1387.0           1534.0        3.392240
# 3       1490.546337           1363.0           1638.0        4.263301
# 4       1376.935386           1287.0           1617.0        3.834336
#
#                                             geometry
# 0  MULTIPOLYGON (((37.59968 0.40029, 37.59976 0.4...
# 1  MULTIPOLYGON (((34.59938 -0.65054, 34.60006 -0...
# 2  MULTIPOLYGON (((34.61175 -0.73357, 34.61183 -0...
# 3  MULTIPOLYGON (((34.61751 -0.87293, 34.6175 -0....
# 4  MULTIPOLYGON (((34.55349 -0.75193, 34.55364 -0...

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ward                 1450 non-null   object
#  1   subcounty            1450 non-null   object
#  2   county               1450 non-null   object
#  3   pop2009              1450 non-null   float64
#  4   flooded              1450 non-null   int64
#  5   rain_cumulative_mm   1450 non-null   float64
#  6   rain_max_daily_mm    1450 non-null   float64
#  7   rain_preflood_7d_mm  1450 non-null   float64
#  8   elevation_mean_m     1450 non-null   float64
#  9   elevation_min_m      1450 non-null   float64
#  10  elevation_max_m      1450 non-null   float64
#  11  slope_mean_deg       1450 non-null   float64
#  12  geometry             1450 non-null   geometry
# dtypes: float64(8), geometry(1), int64(1), object(3)
# memory usage: 147.4+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 2. Create features and target
#
# I will engineer a new feature: `elevation_range_m`, that is the difference between the maximum (`elevation_max_m`) and minimum (`elevation_min_m`) elevations. Thi is important because places with steeper slopes i.e. greater elevation ranges tend to flood less compared to flat areas with lower eleation ranges.

# %%
df['elevation_range_m'] = df['elevation_max_m'] - df['elevation_min_m']

df.head()
# Out:
#                      ward          subcounty  county  pop2009  flooded  \
# 0                  WABERA  Isiolo Sub County  ISIOLO  17431.0        0
# 1    North Kamagambo Ward   Rongo Sub County  Migori  18755.0        0
# 2  Central Kamagambo Ward   Rongo Sub County  Migori  27756.0        0
# 3    South Kamagambo Ward   Rongo Sub County  Migori  27179.0        0
# 4        North Sakwa Ward  Awendo Sub County  Migori  22874.0        0
#
#    rain_cumulative_mm  rain_max_daily_mm  rain_preflood_7d_mm  \
# 0            0.000000           0.000000             0.000000
# 1          258.608840          14.135786            39.955728
# 2          125.951383           8.779010            20.537484
# 3           45.941367           5.696220            10.762588
# 4           78.351185           4.580237            10.795914
#
#    elevation_mean_m  elevation_min_m  elevation_max_m  slope_mean_deg  \
# 0       1099.219448           1026.0           1177.0        1.413028
# 1       1405.549444           1350.0           1508.0        2.246821
# 2       1462.532567           1387.0           1534.0        3.392240
# 3       1490.546337           1363.0           1638.0        4.263301
# 4       1376.935386           1287.0           1617.0        3.834336
#
#                                             geometry  elevation_range_m
# 0  MULTIPOLYGON (((37.59968 0.40029, 37.59976 0.4...              151.0
# 1  MULTIPOLYGON (((34.59938 -0.65054, 34.60006 -0...              158.0
# 2  MULTIPOLYGON (((34.61175 -0.73357, 34.61183 -0...              147.0
# 3  MULTIPOLYGON (((34.61751 -0.87293, 34.6175 -0....              275.0
# 4  MULTIPOLYGON (((34.55349 -0.75193, 34.55364 -0...              330.0

# %%
df.columns
# Out:
# Index(['ward', 'subcounty', 'county', 'pop2009', 'flooded',
#        'rain_cumulative_mm', 'rain_max_daily_mm', 'rain_preflood_7d_mm',
#        'elevation_mean_m', 'elevation_min_m', 'elevation_max_m',
#        'slope_mean_deg', 'geometry', 'elevation_range_m'],
#       dtype='object')

# %%
# Drop geometry and metadata columns
feature_columns = [
    'pop2009',
    'rain_cumulative_mm',
    'rain_max_daily_mm',
    'rain_preflood_7d_mm',
    'elevation_mean_m',
    'elevation_min_m',
    'elevation_max_m',
    'elevation_range_m',
    'slope_mean_deg'
]

target_column = 'flooded'

# Features
X = df[feature_columns]
y = df[target_column]

X.head()
# Out:
#    pop2009  rain_cumulative_mm  rain_max_daily_mm  rain_preflood_7d_mm  \
# 0  17431.0            0.000000           0.000000             0.000000
# 1  18755.0          258.608840          14.135786            39.955728
# 2  27756.0          125.951383           8.779010            20.537484
# 3  27179.0           45.941367           5.696220            10.762588
# 4  22874.0           78.351185           4.580237            10.795914
#
#    elevation_mean_m  elevation_min_m  elevation_max_m  elevation_range_m  \
# 0       1099.219448           1026.0           1177.0              151.0
# 1       1405.549444           1350.0           1508.0              158.0
# 2       1462.532567           1387.0           1534.0              147.0
# 3       1490.546337           1363.0           1638.0              275.0
# 4       1376.935386           1287.0           1617.0              330.0
#
#    slope_mean_deg
# 0        1.413028
# 1        2.246821
# 2        3.392240
# 3        4.263301
# 4        3.834336

# %% [markdown]
# ## 3. Preprocessing
#
# First perform standard **train-test split**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2026, stratify=y, test_size=0.3)

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1015 entries, 454 to 845
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pop2009              1015 non-null   float64
#  1   rain_cumulative_mm   1015 non-null   float64
#  2   rain_max_daily_mm    1015 non-null   float64
#  3   rain_preflood_7d_mm  1015 non-null   float64
#  4   elevation_mean_m     1015 non-null   float64
#  5   elevation_min_m      1015 non-null   float64
#  6   elevation_max_m      1015 non-null   float64
#  7   elevation_range_m    1015 non-null   float64
#  8   slope_mean_deg       1015 non-null   float64
# dtypes: float64(9)
# memory usage: 79.3 KB

# %% [markdown]
# For neural networks, standardization of the features and targets has to be done.
#
# `y` is a binary column. Thus, it does not need to be standardized

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_scaled.shape
# Out:
# (1015, 9)

# %% [markdown]
# Due to the limited size of the dataset, we will not have validation data.

# %% [markdown]
# ## 4. Modelling
#
# I will use Keras' API to build the ANN.
#
# I will ensure I use a balanced class weight to account for class imbalance
#
# I will experiment with three types of regularization to see which results in the best metrics:
#  - l1 regularization
#  - l2 regularization
#  - dropout regularization
#
# I will also build a model that implements **Early Stopping**
#
# I will start by building a baseline model that has no regularization whatsoever

# %%
# Computing class weights
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y),
    y=y
)

class_dict = dict(enumerate(class_weights))

class_dict
# Out:
# {0: 0.6342957130358705, 1: 2.3615635179153096}

# %%
# Baseline model
import keras
from keras import models, layers

# Instantiate
baseline_model = models.Sequential()
input_shape = (X_train_scaled.shape[1],)

# Add input layer
baseline_model.add(layers.Input(input_shape))

# Add hidden layers
baseline_model.add(layers.Dense(50, activation='relu'))
baseline_model.add(layers.Dense(25, activation='relu'))

# Add output layer
baseline_model.add(layers.Dense(1, activation='sigmoid'))

# Define a helper function to compile and fit the model and return history
def compile_and_fit(model, X_train=X_train_scaled, y_train=y_train, class_dict=class_dict):
    # Compile
    model.compile(
        optimizer='sgd',
        loss='binary_crossentropy',
        # I will track recall, auc, f1-score and accuracy
        metrics=[
            'accuracy',
            keras.metrics.Recall(name='recall'),
            keras.metrics.AUC(name='auc'),
            keras.metrics.F1Score()
        ]
    )

    # Fit the model
    history = model.fit(
        X_train,
        y_train,
        epochs=100,
        batch_size=200,
        class_weight=class_dict
    )

    return history

baseline_history = compile_and_fit(baseline_model)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778503223.327124 1052825 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# W0000 00:00:1778503227.416642 1052855 cuda_executor.cc:1755] Failed to determine cuDNN version (Note that this is expected if the application doesn't link the cuDNN plugin): INTERNAL: cuDNN error: CUDNN_STATUS_INTERNAL_ERROR
# W0000 00:00:1778503227.480630 1052825 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7005 - auc: 0.7140 - f1_score: 0.3496 - loss: 0.6350 - recall: 0.5767
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7330 - auc: 0.7317 - f1_score: 0.3496 - loss: 0.6268 - recall: 0.5814
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7596 - auc: 0.7486 - f1_score: 0.3496 - loss: 0.6192 - recall: 0.5767
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7675 - auc: 0.7631 - f1_score: 0.3496 - loss: 0.6115 - recall: 0.5767
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7754 - auc: 0.7769 - f1_score: 0.3496 - loss: 0.6052 - recall: 0.6047
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7773 - auc: 0.7866 - f1_score: 0.3496 - loss: 0.5987 - recall: 0.6140
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7833 - auc: 0.7968 - f1_score: 0.3496 - loss: 0.5917 - recall: 0.6326
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7842 - auc: 0.8051 - f1_score: 0.3496 - loss: 0.5860 - recall: 0.6372
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7872 - auc: 0.8110 - f1_score: 0.3496 - loss: 0.5805 - recall: 0.6465
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7882 - auc: 0.8170 - f1_score: 0.3496 - loss: 0.5748 - recall: 0.6558
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7901 - auc: 0.8206 - f1_score: 0.3496 - loss: 0.5698 - recall: 0.6558
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7911 - auc: 0.8243 - f1_score: 0.3496 - loss: 0.5649 - recall: 0.6558
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7931 - auc: 0.8279 - f1_score: 0.3496 - loss: 0.5609 - recall: 0.6651
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7931 - auc: 0.8306 - f1_score: 0.3496 - loss: 0.5571 - recall: 0.6558
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7961 - auc: 0.8325 - f1_score: 0.3496 - loss: 0.5537 - recall: 0.6651
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7931 - auc: 0.8664 - f1_score: 0.3496 - loss: 0.4651 - recall: 0.7953
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7941 - auc: 0.8663 - f1_score: 0.3496 - loss: 0.4647 - recall: 0.8000
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7941 - auc: 0.8666 - f1_score: 0.3496 - loss: 0.4641 - recall: 0.8000
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7941 - auc: 0.8668 - f1_score: 0.3496 - loss: 0.4636 - recall: 0.8000
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7931 - auc: 0.8672 - f1_score: 0.3496 - loss: 0.4630 - recall: 0.7953
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7941 - auc: 0.8672 - f1_score: 0.3496 - loss: 0.4625 - recall: 0.8000
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7941 - auc: 0.8673 - f1_score: 0.3496 - loss: 0.4620 - recall: 0.8000
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7941 - auc: 0.8673 - f1_score: 0.3496 - loss: 0.4615 - recall: 0.7953
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7961 - auc: 0.8675 - f1_score: 0.3496 - loss: 0.4611 - recall: 0.7953
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7970 - auc: 0.8676 - f1_score: 0.3496 - loss: 0.4606 - recall: 0.7953
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7970 - auc: 0.8677 - f1_score: 0.3496 - loss: 0.4602 - recall: 0.7953
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7980 - auc: 0.8677 - f1_score: 0.3496 - loss: 0.4598 - recall: 0.7953
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7951 - auc: 0.8677 - f1_score: 0.3496 - loss: 0.4595 - recall: 0.8000
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7961 - auc: 0.8679 - f1_score: 0.3496 - loss: 0.4590 - recall: 0.8000
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7941 - auc: 0.8680 - f1_score: 0.3496 - loss: 0.4585 - recall: 0.8000
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7951 - auc: 0.8681 - f1_score: 0.3496 - loss: 0.4581 - recall: 0.8000
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7931 - auc: 0.8684 - f1_score: 0.3496 - loss: 0.4577 - recall: 0.8047
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7951 - auc: 0.8686 - f1_score: 0.3496 - loss: 0.4574 - recall: 0.8047

# %%
print(baseline_history.history.keys())
# Out:
# dict_keys(['accuracy', 'auc', 'f1_score', 'loss', 'recall'])

# %% [markdown]
# Let's visualize the performance of the model per epoch

# %%
# Helper function to visualize metrics
import matplotlib.pyplot as plt
import seaborn as sns

def visualize_metrics(history):
    metrics = list(history.history.keys())
    colors = sns.color_palette('bright', len(metrics))

    fig, axs = plt.subplots(len(metrics), figsize=(15, 10))

    for i, metric in enumerate(metrics):
        ax = axs.flatten()[i]

        ax.set_title(f"{metric.title()} per epoch")
        ax.set_xlabel('Epoch')
        ax.set_ylabel(f'{metric.title()}')

        ax.plot(range(1, len(history.history[metric]) + 1), history.history[metric], color=colors[i], lw=2)
    
    fig.suptitle("Metrics per Epoch")
    plt.show()

# %%
visualize_metrics(baseline_history)

# %% [markdown]
# F1_Score does not change while recall gets worse. The other metrics improve over time
#
# I will now evaluate the model on the test set

# %%
# Helper function to evaluate model and return evaluation metrics
def evaluate_model(model, history, X_test=X_test_scaled, y_test=y_test):
    test_metrics = model.evaluate(X_test, y_test)

    return dict(zip(history.history.keys(), test_metrics))

evaluate_model(baseline_model, baseline_history)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7655 - auc: 0.8187 - f1_score: 0.3491 - loss: 0.5316 - recall: 0.7717
# {'accuracy': 0.5316190719604492,
#  'auc': 0.7655172348022461,
#  'f1_score': 0.77173912525177,
#  'loss': 0.8186874389648438,
#  'recall': 0.3491460978984833}

# %% [markdown]
# Pretty terrible performance. I will now apply regularization to see if it helps
#
# ### a) l1 regularization
